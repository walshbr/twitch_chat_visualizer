# %%
# This is a little program made for parsing out irc Twitch chat log files generated by Twitch Chat Downloader (https://github.com/PetterKraabol/Twitch-Chat-Downloader/) into .csv files

import pandas as pd
import csv
import string
import os

# Manually change file ext from .irc to .txt before use
dirid="/Users/admin/Desktop/Thesis/hasan_logs/nicki/day1/"
docid ="v1148677141"
logname=dirid + docid + ".txt"

raw_log=pd.read_csv(logname,header=None,delimiter='\n',error_bad_lines=False,encoding='utf-8')

raw_log['raw_str']=raw_log[0]
raw_log1=raw_log['raw_str'].str.split(']', n = 1, expand = True)
raw_log2=raw_log1[1].str.split('>', n = 1, expand = True)
parsed_log=pd.concat([raw_log1,raw_log2], axis=1, join='inner')
parsed_log.columns=['timecode','raw','username','message']
parsed_log=parsed_log.drop(columns='raw')
parsed_log['username']=parsed_log['username'].map(lambda x: x.lstrip(' <'))
parsed_log['timecode']=parsed_log['timecode'].map(lambda x: x.lstrip(' ['))
parsed_log['timecode']=parsed_log['timecode'].replace({',':':'}, regex=True)

parsed_log.to_csv(dirid + docid + ".csv",index=False)

# parsed_log.head(30)
# Out:
#        timecode        username  \
# 0   0:00:05:744  assaultkifIe47
# 1   0:00:05:876    Thunderstrum
# 2   0:00:05:917   keepitreal200
# 3   0:00:06:320   MatthausGames
# 4   0:00:06:360    smol_wolfboi
# 5   0:00:06:498     runniebunny
# 6   0:00:06:547          maulds
# 7   0:00:06:583           JECZ7
# 8   0:00:06:712       femmejean
# 9   0:00:06:790   onion_person_
# 10  0:00:07:001       spino_lyp
# 11  0:00:07:510        Dona_kwe
# 12  0:00:07:535     peach_ciroc
# 13  0:00:07:673       mezkinman
# 14  0:00:07:691       KailuaPig
# 15  0:00:07:815  okaythisiserik
# 16  0:00:07:825          InvizG
# 17  0:00:08:063  CaulfielderRye
# 18  0:00:08:204      irisdotmov
# 19  0:00:08:278        yahmadya
# 20  0:00:08:423    GrawvyRobber
# 21  0:00:08:717       talentedg
# 22  0:00:08:824   AmperianLoops
# 23  0:00:08:898    skootTheBoot
# 24  0:00:08:982         linknl1
# 25  0:00:09:112     Senthan2002
# 26  0:00:09:232      KrazyKefka
# 27  0:00:09:328     Succculence
# 28  0:00:09:422     JunieBTones
# 29  0:00:09:629    mongenavarro
#
#                                               message
# 0                                    BAITER WeirdDude
# 1                                                PogU
# 2                                                PogU
# 3                                                PogU
# 4                         cock is nice oliver i agree
# 5                                                PogU
# 6                                              LETSGO
# 7                                                PogU
# 8                                 LETS GOOOOOOOOOOOOO
# 9                                                KEKW
# 10                                               PogU
# 11                                               PogU
# 12                                               PogU
# 13                 LETSGO LETSGO LETSGO LETSGO LETSGO
# 14                                     widepeepoHappy
# 15                                          live PogU
# 16                                           AlienPls
# 17                                        HYPERPOGGER
# 18                                                 um
# 19                                               PogU
# 20   Hey Chat peepoHey peepoHey peepoHey !!!!! I w...
# 21                                        dsaChudding
# 22                                               PogU
# 23                                               PogU
# 24                                          LETS GOOO
# 25                                               PogU
# 26                                        LETSGO Clap
# 27                                         GRILL PogU
# 28                                                 yo
# 29                                                Pog
